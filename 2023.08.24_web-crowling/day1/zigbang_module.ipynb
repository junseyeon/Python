# %%
import zigbang as zb

# %%
# %ls
# Out:
#  C 드라이브의 볼륨: WINDOWS
#  볼륨 일련 번호: 1CE2-C115
#
#  C:\Users\user\python\2023.08.24_웹크롤링_실습자료\day1 디렉터리
#
# 2023-08-24  오후 05:12    <DIR>          .
# 2023-08-24  오전 11:10    <DIR>          ..
# 2023-08-24  오후 05:09    <DIR>          .ipynb_checkpoints
# 2023-08-24  오후 05:12    <DIR>          __pycache__
# 2023-08-24  오후 03:34           628,700 01_requests_naver_stock.ipynb
# 2023-08-24  오후 02:52             4,402 02_requests_daum_exchange.ipynb
# 2023-08-24  오후 04:28            12,750 03_naver_api.ipynb
# 2023-08-24  오후 05:08         1,521,780 04_requests_zigbang.ipynb
# 2023-08-24  오후 02:53            10,060 covid.xlsx
# 2023-08-24  오후 03:43             5,708 en_covid.xlsx
# 2023-08-24  오후 05:12             1,061 zigbang.py
# 2023-08-24  오후 05:12             2,044 zigbang_module.ipynb
#                8개 파일           2,186,505 바이트
#                4개 디렉터리  145,347,846,144 바이트 남음

# %%
df = zb.oneroom('성수동')
df
# Out:
#     item_id                             title  deposit  rent       address1  \
# 0  37729835   즉시입주가능 실사용15평 서울숲 신축 첫입주 풀옵션 복층     5000   210  서울시 성동구 성수동1가
# 1  37792348     최저가 실사용 8평 서울숲 신축 복층 풀옵션 오피스텔     1000   120  서울시 성동구 성수동1가
# 2  37760627  뚝섬역, 서울숲역 더블역세권, 2룸, 풀옵션, 빠른입주가능    18000     0  서울시 성동구 성수동1가
# 3  37761371          뚝섬역 2분   2룸 전세. 즉시입주 가능.    18000     0  서울시 성동구 성수동1가
# 4  37687433   핫한 서울숲 메인 올수리후 첫입주 내부 깔끔 즉시 입주가     5000   140  서울시 성동구 성수동1가
# 5  37819652            서울숲 아뜰리에 길에 위치한 주택 ,2룸     5000   140  서울시 성동구 성수동1가
# 6  37553738                    전용넓은 쓰리룸, 즉시입주     5000   150  서울시 성동구 성수동1가
# 7  37760472           2룸  2억2천  전세   내부상태 좋아요    22000     0  서울시 성동구 성수동1가
# 8  37750742                   깨끗하고 조용한 주택가 투룸    15000    60  서울시 성동구 성수동1가
# 9  37707091  뚝섬역 2분거리, 3룸, 상태깨끗, 8월 중순이후 입주가능     4000   100  서울시 성동구 성수동1가
#
#    size_m2 manage_cost
# 0    51.25          15
# 1    27.50          12
# 2    42.98           0
# 3    54.23           2
# ...

# %%
df = zb.oneroom('망원동')
df.tail(2)
# Out:
#      item_id                title  deposit  rent     address1  size_m2  \
# 57  37804362     신축급즉시입주깔끔원룸 주차가능      300    72  서울시 마포구 망원동    19.83
# 58  37811722  리모델링후 첫입주 쓰리룸월세 풀옵션     2000   110  서울시 마포구 망원동    48.00
#
#    manage_cost
# 57           7
# 58           1
